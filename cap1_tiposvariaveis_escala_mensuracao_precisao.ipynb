# %% [markdown]
# <a href="https://colab.research.google.com/github/jvataidee/ManualdeAnalisedeDados_Python/blob/master/cap1_tiposvariaveis_escala_mensuracao_precisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **by: [João Ataíde](https://www.joaoataide.com)**
# # **CAP 01: Tipos Variáveis Escala Mensuração e Precisão**
#
# ---

# %%
#importar bibliotecas
import pandas as pd
import numpy as np
import math

# %% [markdown]
# *   `Variáveis não métrias: ` variáveis categóricas/qualitativas, representa características individuais que não podem ser medidas
# *   `Variáveis métricas: ` representa caracteríticas individuais resultados de contagem ou mensurações.

# %% [markdown]
# ## Variáveis não métricas

# %%
#Criando dados
clas_salarios = [['A', 'Acima de 20 SM', 'Acima de R$ 15760.00'],
                ['B', '10 a 20 SM', 'De R$7880.00 a R$15760.00'],
                ['C', '4 a 10 SM', 'De R$3152.00 a R$7880.00'],
                ['D', '2 a 4 SM', 'Até 2 Sm'],
                ['E', 'Até 2 Sm', 'Até R$1576.00']]

colunas = ['Classe', 'Slário Mínimo (SM) ', 'Renda Familiar (RF)']

# %%
#Mostrando DataFrame
clas_salrios = pd.DataFrame(clas_salarios)
clas_salrios.columns = colunas
clas_salrios
# Out:
#   Classe Slário Mínimo (SM)         Renda Familiar (RF)
# 0      A      Acima de 20 SM       Acima de R$ 15760.00
# 1      B          10 a 20 SM  De R$7880.00 a R$15760.00
# 2      C           4 a 10 SM   De R$3152.00 a R$7880.00
# 3      D            2 a 4 SM                   Até 2 Sm
# 4      E            Até 2 Sm              Até R$1576.00

# %% [markdown]
# Note que os dados são dividido por faixas, sendo então qualitativos. Para esse caso podemos realizar cálculos de frequência e não medias de resumo como médias e desvios padrão.
#
# `OBS` *Cuidado ao usar as informções numéricas dessas faixar, não utilize como se fosse um dado quantitativo.*

# %% [markdown]
# Mas podemos ver por exemplo o quanto cada uma das classe se repeque, no caso a frequência dessa classe.

# %%
df["Frequência"] = ["10%", "18%", "24%", "36%", "12%"]
df
# Out:
#     Nome  Idade   Salário  ...  Classe  Rótulo Frequência
# 0   João      48     5000  ...       D      12        10%
# 1  Maria      23     1500  ...       C      25        18%
# 2   José      47     9000  ...       C      12        24%
# 3  Frank      19      400  ...       D      32        36%
# 4  Mario      33     3400  ...       D      45        12%
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Variáveis métrica

# %% [markdown]
# Variáveis quantitativas podem ser representadas por gráficos de linha, dispersão, histograms ..., podemos usar medidas de posição e localização como média, mediana, moda, quatis ... e medidas de dispersão como amplitude, desvios, veriância ...

# %%
#Criando dados
dados = [['João', 48, 5000, 4, 2000, 'Brasil', 'D'],
         ['Maria', 23, 1500, 1, 5000, 'Argentina', 'C'],
         ['José', 47, 9000, 10, 9000, 'Brasil', 'C'],
         ['Frank', 19, 400, 0, 3000, 'Marrocos', 'D'],
         ['Mario', 33, 3400, 3, 3400, 'Alemanhã', 'D']]


colunas = ['Nome', 'Idade ', 'Salário', 'Tempo Experiência', 'Renda Familiar', 'Pais de Origem', 'Classe']

# %%
df = pd.DataFrame(dados)
df.columns = colunas
df
# Out:
#     Nome  Idade   Salário  ...  Renda Familiar  Pais de Origem Classe
# 0   João      48     5000  ...            2000          Brasil      D
# 1  Maria      23     1500  ...            5000       Argentina      C
# 2   José      47     9000  ...            9000          Brasil      C
# 3  Frank      19      400  ...            3000        Marrocos      D
# 4  Mario      33     3400  ...            3400        Alemanhã      D
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nome               5 non-null      object
#  1   Idade              5 non-null      int64
#  2   Salário            5 non-null      int64
#  3   Tempo Experiência  5 non-null      int64
#  4   Renda Familiar     5 non-null      int64
#  5   Pais de Origem     5 non-null      object
#  6   Classe             5 non-null      object
# dtypes: int64(4), object(3)
# memory usage: 408.0+ bytes

# %% [markdown]
# Note que a unica variável textual é o nome da pessoa, pais de origem e classe e pode ser medida em escala nominal. Já as demais são quantitativa e numericas e podem sofrer mensuração.

# %% [markdown]
# ## Tipos de Variáveis VS Escalas de Mensuração
#
# `Mensuração: ` Processo de atribuir número/rótulos aos objetos de estudo, com base nas regras específicas para representar as quantidades ou qualidades dos atributos.
#
# `Regra: ` é um guia, método ou comando que indica como media o atributo.
#
# `Escala: ` é um conjunto de símbolos ou números que são construidos na base da regra e aplica-se ao objeto individual.

# %% [markdown]
# * `Variáveis Qualitativas` $->$ Nominal ou Ordinal
# * `Variáveis Quantitativas` $->$ Intervalar ou Razão

# %% [markdown]
# ### Escala Nomianal
# Variáveis não métricas
#
# O nome dessa escala é data pois não estabelece qualquer grandeza ou ordem, sendo então somente diferenciadas pelos nomes.
#
# Uma forma de trabalhar é atribuindo rótudos numéricos às categorias das variáveis, mas operações aritiméticas não são admissíveis. Podemos contar o número de elemento de uma classe, fazer um teste de hipótese.
#
# Ex: *Profissão, Religião, Cor, Estado Civil, localização geográfica.*
#
# `OBS` *Maiorias das estatíticas não possuem sentido para dados nominais, como média e desvio-padrão.*

# %% [markdown]
# Podemos pro exemplo representar/etiquetar e facilitar a identificação de uma determinda classe de objeto.

# %%
#Representação por rótulos numéricos
rep_nominal = {"Brasil": 12, "Argentina":25, "Marrocos":32, "Alemanhã": 45}
df["Rótulo"] = df["Pais de Origem"].replace(rep_nominal)
df
# Out:
#     Nome  Idade   Salário  ...  Pais de Origem  Classe Rótulo
# 0   João      48     5000  ...          Brasil       D     12
# 1  Maria      23     1500  ...       Argentina       C     25
# 2   José      47     9000  ...          Brasil       C     12
# 3  Frank      19      400  ...        Marrocos       D     32
# 4  Mario      33     3400  ...        Alemanhã       D     45
#
# [5 rows x 8 columns]

# %% [markdown]
# Esse tipo de escala é conhecido como escala nominal e são atribuidos aleatoriamente as categorias, com isso feito podemos representar a natureza destes por meio de tabelas de distribuição, frequência, gráficos de barra ou setores e o cálculo da moda.

# %%
cont_pais = pd.DataFrame(df.iloc[:, [5, 7]].value_counts())
cont_pais
# Out:
#                        0
# Pais de Origem Rótulo
# Brasil         12      2
# Marrocos       32      1
# Argentina      25      1
# Alemanhã       45      1

# %% [markdown]
# Podemos então a a partir dessa trasnformação identificar dentro das pessoas listadas qual o país de origem que mais se repete.

# %%
cont_pais.plot(kind = "bar", figsize = (12, 5));

# %% [markdown]
# ### Escala Ordinal
# Variável não métrica
#
# Básicamente é uma variável categórica em uma escala ordinal que designa uma posição relativa da classe seguindo uma direção. Assim como a escala nominal operações aritiméticas não fazem sentido, assim podemo realizar apenas estatíticas descritivas usuais limitadas como na nominal. Assim pode-se calcula tabelas de distribuição, frequência, gráficos ...
#
# *Ex: Escala de opinião, escalas de preferência, grau de escolaridade, classe social, faixa etária ...*

# %%
escala_valores = pd.DataFrame([[1, "Péssimo"],
                               [2, "Ruim"],
                               [3, "Regular"],
                               [4, "Bom"],
                               [5, "Muito Bom"]])

escala_valores.columns = ["Valor", "Rótulo"]
escala_valores
# Out:
#    Valor     Rótulo
# 0      1    Péssimo
# 1      2       Ruim
# 2      3    Regular
# 3      4        Bom
# 4      5  Muito Bom

# %% [markdown]
# Ao invez de usar uma escala de 1-5 poderia ser usado qualquer outra escala numérica desde que a ordem da classificação fosse respeitada, de modo que os atributos analisados não se diferenciem.

# %%
clas_salrios
# Out:
#   Classe Slário Mínimo (SM)         Renda Familiar (RF)
# 0      A      Acima de 20 SM       Acima de R$ 15760.00
# 1      B          10 a 20 SM  De R$7880.00 a R$15760.00
# 2      C           4 a 10 SM   De R$3152.00 a R$7880.00
# 3      D            2 a 4 SM                   Até 2 Sm
# 4      E            Até 2 Sm              Até R$1576.00

# %%
cont_classe = pd.DataFrame(df["Classe"].value_counts()).reset_index()
cont_classe.rename(columns={"Classe":"Pessoas", "index":"Classe"}, inplace = True)
cont_classe = pd.merge(clas_salrios, cont_classe, how = "left", on = ["Classe"])
cont_classe = cont_classe[cont_classe["Pessoas"]>0]
cont_classe
# Out:
#   Classe Slário Mínimo (SM)        Renda Familiar (RF)  Pessoas
# 2      C           4 a 10 SM  De R$3152.00 a R$7880.00      2.0
# 3      D            2 a 4 SM                  Até 2 Sm      3.0

# %% [markdown]
# ### Escala Intervalar
# Variável quantitativa
#
# Básicamente são variáveis métrica que além de ordenar as unidades quanto à caracteríticas mesuradas, possui uma unidade de medida, como: Temperatura (°C, °F e K) e comprimento (cm, m, km, dm ..).
#
# Escalas intervalar é invariante sob transformação linerares positias de modo que uma escala pode ser trasnformada em outra por meio de uma transformação linear, como converter de  °F para °C e de cm para m

# %%
#Converter de Centrimetro para Metro
def converter_cm_m(medicao):
    return print(f"{medicao * 0.01} m")

# %%
converter_cm_m(100)
# Out:
# 1.0 m

# %%
#Converter Fahrenheit para Celsius
def converter_f_c(medicao):
    return print(f"{np.round((medicao -32)* 5/9, 2)}" "°C")

# %%
converter_f_c(10)
# Out:
# -12.22°C

# %% [markdown]
# ### Escala de razão
# Variável quantitativa
#
# Essa escala é analoga a intervalar e ordena as unidades em relação às caracteríticas mesuradas e possuem uma unidade de media constante, entretanto o ponto zero ou origem desses dados é o único valor zero e significa a ausência de quantidade.
#
# Razões iguai consresponde a razão mesurada, assim as escalas são invatiantes, por exemplo uma unidade com 1 metro e outra com 3 metros, pode-se deduzir que a segunda tem 3 vezes a primeira.
#
# *EX: Renda, idade, quantidade produzida de determinado produto, distância percorrida*

# %%
joao = df[df["Nome"] == 'João']
jose = df[df["Nome"] == "José"]

# %%
#Indice salarial
print(f"Salário João é de R$ {int(joao.Salário)}")
print(f"Salário José é de R$ {int(jose.Salário)}")

print(f"Diferença de salário entre João e José é de: R$ {np.round(int(joao.Salário) - int(jose.Salário), 2)}")
print(f"João ganha {np.round(int(joao.Salário) / int(jose.Salário) *100, 2)}% menos que José")
# Out:
# Salário João é de R$ 5000
# Salário José é de R$ 9000
# Diferença de salário entre João e José é de: R$ -4000
# João ganha 55.56% menos que José

# %% [markdown]
# ## Tipos de Variáveis vs Número de Categorias e Escala de Precisão
#
# *   `Categórica`$->$ Dicotômica/Biária ou Policotômica
# *   `Métrica`$->$ Discreta ou Contínua

# %% [markdown]
# ### Variáveis dicotômica ou binária (dummy)
# Variáveis não métricas
#
# Esse tipo de variável só pode assumir duas categorias sendo `0`a ausênsia e `1`presença dessa categoraia.
#
# *EX: Fumante (1) e não Fumante (0)*

# %%
df_dummy = pd.get_dummies(df, columns=["Classe"])
df_dummy["Classe_A"] = 0
df_dummy["Classe_B"] = 0
df_dummy["Classe_E"] = 0
df_dummy[["Nome", "Classe_C", "Classe_D",  "Classe_A",  "Classe_B", "Classe_E"]]
# Out:
#      Nome  Classe_C  Classe_D  Classe_A  Classe_B  Classe_E
# 0    João         0         1         0         0         0
# 1   Maria         1         0         0         0         0
# 2    José         1         0         0         0         0
# 3   Frank         0         1         0         0         0
# 4   Mario         0         1         0         0         0
# 5  Manoel         0         0         0         0         0

# %% [markdown]
# ### Variável Policotômica
# Variáveis não métricas
#
# Neste caso pode-se assumir mais de uma categoria.
#
# *EX: Baixa renda (1), média renda (2), alta renda (3)*

# %%
novo_dado = {"Nome":"Manoel", "Idade ":33, "Salário":1200, "Tempo Experiência":1,
             "Renda Familiar":1200, "Pais de Origem":"Brasil", "Classe":"E"}
#Adicioandno novo dado no Data Frame
df = df.append(novo_dado, ignore_index=True)
df
# Out:
#      Nome  Idade   Salário  ...  Pais de Origem  Classe Rótulo
# 0    João      48     5000  ...          Brasil       D    1.0
# 1   Maria      23     1500  ...       Argentina       C    0.0
# 2    José      47     9000  ...          Brasil       C    0.0
# 3   Frank      19      400  ...        Marrocos       D    1.0
# 4   Mario      33     3400  ...        Alemanhã       D    1.0
# 5  Manoel      33     1200  ...          Brasil       E    NaN
#
# [6 rows x 8 columns]

# %%
#Criando rotulos de várias classes
df["Rótulo"] = df.Classe.astype("category").cat.codes
df[["Nome", "Classe", "Rótulo"]]
# Out:
#      Nome Classe  Rótulo
# 0    João      D       1
# 1   Maria      C       0
# 2    José      C       0
# 3   Frank      D       1
# 4   Mario      D       1
# 5  Manoel      E       2

# %% [markdown]
# ### Variável discretas
# Variáveis métricas
#
# Como dito, pode assuimir um conjunto finito ou valores enumeráveis que são proveniente, podem ser calculado a frequência, contagem.
#
# *EX: número de filhos*

# %%
novo_dados_filhos = pd.DataFrame([0, 2, 1, 0, 3, 0])

#Adicioandno novo dado no Data Frame
df["Filhos"] = novo_dados_filhos
df[["Nome", "Filhos" ]]
# Out:
#      Nome  Filhos
# 0    João       0
# 1   Maria       2
# 2    José       1
# 3   Frank       0
# 4   Mario       3
# 5  Manoel       0

# %% [markdown]
# ### Variável Contínuas
# Variáveis métricas
#
# Estes são os conjuntos cujo possíveis valores pertencem a um intervalo de números reais ($\in \mathbb{R}$) e resultam de uma mensuração métrica.
#
# *EX: Pesom Altura, Salário ... *

# %%
df[["Nome", "Salário" ]]
# Out:
#      Nome  Salário
# 0    João     5000
# 1   Maria     1500
# 2    José     9000
# 3   Frank      400
# 4   Mario     3400
# 5  Manoel     1200
